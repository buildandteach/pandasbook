# %%
import pandas as pd

data = pd.read_clipboard()
data
# Out:
#    Student Name  Quiz 1  Quiz 2  Test 1  Quiz 3  Quiz 4  Test 2  Quiz 4.1  \
# 0      John One      85      65      90      90      78      60        70
# 1      Paul Two      68      74      86     100      96      90        70
# 2    Jane Three      97      60      88      84      93      91        66
# 3     Greg Four      66      88      74      82      81     100        77
# 4     Mary Five      91      72      80      81      98      75        80
# 5     Bobby Six      92      73      98      66      71      93       100
# 6  Steven Seven      60      80      74      96      65      83        65
# 7   Terry Eight      92      71      67      83      75      74        92
# 8   Vivian Nine      88      95      97      95      62     100        84
# 9     Riley Ten      97      86      72      90      97      94        90
#
#    Quiz 5  Final Exam
# 0      82          73
# 1      74          66
# 2      76          86
# 3      66          71
# 4      76          73
# ...

# %%
data.to_csv("studentdata.csv")

# %%
data.to_pickle("studentdata.pkl")

# %%
#must have feather installed in terminal use conda install feather-format -c conda-forge
data.to_feather("studentdata.feather")

# %%
dict = data.to_dict()
dict
# Out:
# {'Final Exam': {0: 73,
#   1: 66,
#   2: 86,
#   3: 71,
#   4: 73,
#   5: 73,
#   6: 83,
#   7: 96,
#   8: 99,
#   9: 93},
#  'Quiz 1': {0: 85,
#   1: 68,
#   2: 97,
#   3: 66,
#   4: 91,
#   5: 92,
#   6: 60,
#   7: 92,
#   8: 88,
#   9: 97},
#  'Quiz 2': {0: 65,
#   1: 74,
#   2: 60,
#   3: 88,
#   4: 72,
#   5: 73,
#   6: 80,
#   7: 71,
#   8: 95,
#   9: 86},
#  'Quiz 3': {0: 90,
#   1: 100,
#   2: 84,
#   3: 82,
#   4: 81,
#   5: 66,
#   6: 96,
#   7: 83,
#   8: 95,
#   9: 90},
#  'Quiz 4': {0: 78,
#   1: 96,
#   2: 93,
#   3: 81,
#   4: 98,
#   5: 71,
#   6: 65,
#   7: 75,
#   8: 62,
#   9: 97},
#  'Quiz 4.1': {0: 70,
#   1: 70,
#   2: 66,
#   3: 77,
#   4: 80,
#   5: 100,
#   6: 65,
#   7: 92,
#   8: 84,
#   9: 90},
#  'Quiz 5': {0: 82,
#   1: 74,
#   2: 76,
#   3: 66,
#   4: 76,
#   5: 94,
#   6: 88,
#   7: 79,
#   8: 65,
#   9: 84},
#  'Student Name': {0: 'John One',
#   1: 'Paul Two',
#   2: 'Jane Three',
#   3: 'Greg Four',
#   4: 'Mary Five',
#   5: 'Bobby Six',
# ...
